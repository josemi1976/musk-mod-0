# %% [markdown]
# 1. Escribe una función en python para leer el contenido de un archivo de texto "poema.txt" línea por línea y mostrar el mismo en pantalla.

# %%
def read_file():
    file = open("poem.txt","r")
    for line in file:
        print(line, end="")
    file.close()

read_file()

# %% [markdown]
# 2. Escribe una función para contar el número de líneas de un archivo de texto "historia.txt":
#
# ```
# Ejemplo: Si el archivo "story.txt" contiene las siguientes líneas
# Un niño está jugando allí.
# Hay un parque infantil.
# Un avión está en el cielo.
# El cielo es rosa.
# La contraseña puede contener letras y números.
# ```
# El resultado debe ser 5.

# %%
def line_count():
    file = open("story.txt","r")
    count=0
    for line in file:
            count+= 1
    file.close()
    print("Numero de lineas ",count)

line_count()

# %% [markdown]
# 3. Escribe una función en Python para contar y mostrar el número total de palabras en un archivo de texto.

# %%
def count_words():
    file = open("notes.txt","r")
    count = 0
    data = file.read()
    words = data.split()
    for word in words:
        count += 1
    print("Total words are",count)
    file.close()

count_words()

# %% [markdown]
# 4. Escriba una función en Python para leer líneas de un archivo de texto "notas.txt". Su función debe encontrar y mostrar la aparición de la palabra "el".

# %% [markdown]
# Por ejemplo: Si el contenido del archivo es:
# "La India es una de las economías que más crece a nivel mundial. India está buscando más inversiones en todo el mundo".
#
# La solución debería ser 1.

# %%
def count_words():
    file = open("notes.txt","r")
    count = 0
    data = file.read()
    words = data.split()
    for word in words:
        if word.lower() == 'el':
            count += 1
    print(count)
    file.close()

count_words()

# %% [markdown]
# 5. Escriba una función display_words() en python para leer las líneas de un archivo de texto "story.txt", y mostrar aquellas palabras que tengan menos de 4 caracteres.

# %%
def display_words():
    file = open("story.txt","r")
    data = file.read()
    words = data.split()
    for word in words:
        if len(word) < 4:
            print(word, end=" ")
    file.close()

display_words()

# %% [markdown]
# 6. Un archivo de texto llamado "materia.txt" contiene algún texto, que necesita ser mostrado de manera que cada carácter siguiente esté separado por un símbolo "#". Escriba una definición de función para hash_display() en Python que muestre todo el contenido del archivo matter.txt en el formato deseado.
# Ejemplo : Si el archivo materia.txt tiene el siguiente contenido almacenado :
# EL MUNDO ES REDONDO
#
# La función hash_display() debería mostrar el siguiente contenido :
# T#H#E# #W#O#R#L#D# #I#S# #R#O#U#N#D#

# %%
def count_hash():
    file = open("matter.txt","r")
    data = file.read()
    for letter in data:
        print(letter, end="#")

    file.close()

count_hash()

# %% [markdown]
# 7. Escribe un programa en Python para generar 26 archivos de texto llamados A.txt, B.txt, y así sucesivamente hasta Z.txt.

# %%
import string, os
if not os.path.exists("letters"):
    os.makedirs("letters")
    
for letter in string.ascii_uppercase:
    with open(letter + ".txt", "w") as f:
        f.writelines(letter)

# %% [markdown]
# 8. Escribe un programa en python para añadir texto a un archivo y mostrar el texto en python.txt

# %%
def read_file(file_name):
        from itertools import islice
        with open(file_name, "w") as myfile:
                myfile.write("Python Exercises\n")
                myfile.write("Python Tutorials")
        txt = open(file_name)
        print(txt.read())
        
read_file('python.txt')

# %% [markdown]
# 9. Escribe un programa en python para calcular la frecuencia de a todas las palabras de un archivo txt.

# %%
from collections import Counter
 
def word_count(file_name):
    with open(file_name) as f:
        return Counter(f.read().split())

print("The total number of each words in the file :")
print(word_count("a.txt"))

# Otra opción valida es usar un diccionario, donde las las keys son palabras en minusculas
# y las claves son número de ocurrencias

# %% [markdown]
# 10. Escribe un programa en python para comprobar si un archivo especificado existe.

# %%
import os.path
open('document.txt', 'w')
print(os.path.isfile('document.txt'))
